# %%
import os
import csv

with open('./3D_front_mapping_merged_new.csv', 'r', encoding="utf-8") as csv_file:
    reader = csv.DictReader(csv_file)
    mapping = {}

    for row in reader:
        print(row['name'])
        print(int(row["id"]))
        
#         mapping.add(row[label_col_name], int(row[id_col_name]))
#     return mapping
# Out:
# void
# 0
# smartcustomizedceiling
# 1
# cabinet/lightband
# 2
# tea table
# 3
# cornice
# 4
# sewerpipe
# 5
# children cabinet
# 6
# hole
# 7
# ceiling lamp
# 8
# chaise longue sofa
# 9
# lazy sofa
# 10
# appliance
# 11
# round end table
# 12
# build element
# 13
# dining chair
# 14
# others
# 15
# armchair
# 16
# bed
# 17
# two-seat sofa
# 18
# lighting
# 19
# kids bed
# 20
# pocket
# 21
# storage unit
# 22
# media unit
# 23
# slabside
# 24
# footstool / sofastool / bed end stool / stool
# 25
# 300 - on top of others
# 26
# customizedplatform
# 27
# sideboard / side cabinet / console
# 28
# plants
# 29
# ceiling
# 30
# slabtop
# 31
# pendant lamp
# 32
# lightband
# 33
# electric
# 34
# pier/stool
# 35
# table
# 36
# extrusioncustomizedceilingmodel
# 37
# baseboard
# 38
# front
# 39
# wallinner
# 40
# basin
# 41
# bath
# 42
# customizedpersonalizedmodel
# 43
# baywindow
# 44
# customizedfurniture
# 45
# sofa
# 46
# kitchen cabinet
# 47
# cabinet
# 48
# walltop
# 49
# chair
# 50
# floor
# 51
# customizedceiling
# 52
# 500 - attach to ceiling
# 53
# customizedbackgroundmodel
# 54
# drawer chest / corner cabinet
# 55
# tv stand
# 56
# 400 - attach to wall
# 57
# window
# 58
# art
# 59
# back
# 60
# accessory
# 61
# 200 - on the floor
# 62
# beam
# 63
# stair
# 64
# wine cooler
# 65
# outdoor furniture
# 66
# double bed
# 67
# dining table
# 68
# cabinet/shelf/desk
# 69
# single bed
# 70
# classic chinese chair
# 71
# corner/side table
# 72
# flue
# 73
# shelf
# 74
# customizedfeaturewall
# 75
# nightstand
# 76
# recreation
# 77
# lounge chair / book-chair / computer chair
# 78
# slabbottom
# 79
# dressing table
# 80
# desk
# 81
# column
# 82
# dressing chair
# 83
# wardrobe
# 84
# extrusioncustomizedbackgroundwall
# 85
# electronics
# 86
# bunk bed
# 87
# bed frame
# 88
# three-seat / multi-person sofa
# 89
# customizedfixedfurniture
# 90
# bookcase / jewelry armoire
# 91
# mirror
# 92
# wallbottom
# 93
# barstool
# 94
# wallouter
# 95
# l-shaped sofa
# 96
# customized_wainscot
# 97
# door
# 98
# lounge chair / cafe chair / office chair
# 99
# coffee table
# 100
# king-size bed
# 101
# three-seat / multi-seat sofa
# 102
# sideboard / side cabinet / console table
# 103
# loveseat sofa
# 104
# wine cabinet
# 105
# bar
# 106
# shoe cabinet
# 107
# couch bed
# 108
# hanging chair
# 109
# folding chair
# 110
# u-shaped sofa
# 111
# floor lamp
# 112
# wall lamp
# 113

# %%
a = {'void': 'void', 'smartcustomizedceiling': 'ceiling', 'ceiling': 'ceiling', 'extrusioncustomizedceilingmodel': 'ceiling', 'customizedceiling': 'ceiling', 
 'bed': 'bed', 'kids bed': 'bed', 'footstool / sofastool / bed end stool / stool': 'bed', 'double bed': 'bed', 'single bed': 'bed', 'bunk bed': 'bed', 'bed frame': 'bed', 'king-size bed': 'bed', 'couch bed': 'bed',
 'hanging chair': 'chair', 'folding chair': 'chair','dressing chair': 'chair','dining chair': 'chair','armchair': 'chair','classic chinese chair': 'chair','lounge chair / cafe chair / office chair': 'chair','lounge chair / book-chair / computer chair': 'chair',
    'pendant lamp':'lamp', 'chaise longue sofa':'sofa', 'two-seat sofa':'sofa', 'lazy sofa':'sofa', 'three-seat / multi-person sofa':'sofa', 'three-seat / multi-seat sofa': 'sofa', 'loveseat sofa': 'sofa'
    , 'sideboard / side cabinet / console table': 'cabinet', 'sideboard / side cabinet / console': 'cabinet', 'drawer chest / corner cabinet': 'cabinet',
    '200 - on the floor': 'floor','300 - on top of others': 'others','500 - attach to ceiling': 'ceiling','400 - attach to wall': 'floor','void': 'void','void': 'void'}

# %%
# Get a one scene data
import os
import json
models_info = {}
with open('./scene.json', 'r', encoding="utf-8") as f:
    models_info = json.load(f)

with open('./scene.json', 'r', encoding="utf-8") as f:
    data = json.load(f)
